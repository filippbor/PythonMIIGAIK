# %% [markdown]
# ## Домашнее задание №3

# %% [markdown]
# *Составлено с использованием материалов курса лекций «Программирование на языке Python для сбора и анализа данных» Щурова И.В., НИУ ВШЭ*

# %% [markdown]
# ***В сумме за домашнюю работу вы можете получить 18 баллов.*** <br>
# ***Итоговая оценка будет равна доле полученных баллов от общей суммы x10.***
# <p>
# <font size='3' color="B3000C">Ноутбук (файл в расширением .ipynb) выложите на свой git и пришлите ссылку на почту python.in.miigaik@gmail.com.<br> В теме письма укажите номер домашней работы и номер группы: HW... , Group... .</font>
# </p>

# %% [markdown]
# ### Задача 1 Сортировка (1 балл)
# На вход поступает список из вещественных чисел. Отсортировать его по возрастанию, элементы в отсортированном списке должны иметь 3 знака после запятой.
# <br> **Входные данные**: [1.0,-2.0,3.0].<br> **Выходные данные**: [-2.000,1.000,3.000]

# %%
a = []
n = int(input()) 
b = 3
c = '{:.' + str(b) + 'f}'
for i in range(n):  
    a.append(c.format(float(input())))
print(sorted(a))
# Out:
# 3
# 1.0
# -2.0
# 3.0
# ['-2.000', '1.000', '3.000']

# %% [markdown]
# ### Задача 2 Средний символ (1 балл)
# На вход поступает строка. Ваша задача - вернуть средний символ строки. Если длина строки нечетна, верните средний символ. Если длина строки четная, верните средние 2 символа.
# <br> **Входные данные** : "test". **Выходные данные**: "es"
# <br> **Входные данные** : "sunsets". **Выходные данные**: "s"

# %%
text = input()
a = len(text)
if a % 2 == 0:
    b = a // 2 
    c = b - 1   
    print(text[c],text[b], sep='')
elif a % 2 > 0:
    b = a // 2
    print(text[b])
# Out:
# sunsets
# s

# %% [markdown]
# ### Задача 3 Еще одна задача со строками (1 балл)
# На вход подается предложение из слов. Ваша задача вернуть тоже самое предложение, в котором все слова длины больше 5 записаны в обратном порядке.
# <br> **Входные данные** : "Hey fellow warriors". **Выходные данные**: "Hey wollef sroirraw"
# <br> **Входные данные** : "This is a test". **Выходные данные**: "This is a test"

# %%
text = input().split(' ')

log = []
for word in text:
    if len(word) > 5:
        a = word
        log.append(str(a[::-1]))
    else:
        log.append(str(word))
btext = ' '.join(log)
print(btext)
# Out:
# Hey fellow warriors
# Hey wollef sroirraw

# %% [markdown]
# ### Задача 4 ДНК (1 балл)
# На вход подается строка "ДНК". Ваша цель построить комплиментарную цепь к этой ДНК. Материал для [справки](https://bit.ly/2gyHYCV), как меняются отдельные азотистые основания.
# <br> **Входные данные**: "ATTGC". **Выходные данные**:"TAACG"
# <br> **Входные данные**: "GTAT". **Выходные данные**:"CATA"

# %%
a=input('Введите строку "ДНК": ')
a1=[]
for i in range(len(a)):
    if a[i]=='A':
        a1.append('T')        
    elif a[i]=='T':
        a1.append('A')       
    elif a[i]=='G':
        a1.append('C')        
    elif a[i]=='C':
        a1.append('G')      
    else:
        a1.append('"NF"') # Not Found

print("".join(a1))
# Out:
# Введите строку "ДНК": ATTGC
# TAACG

# %% [markdown]
# ### Задача 5 Танцевальная музыка (1 балл)
# В клубной музыке принято использовать различные звуковые эффекты. Ваша цель очистить строку от музыкального эффекта "BOOM".
# <br> **Входные данные**: "BOOMWEBOOMAREBOOMBOOMTHEBOOMCHAMPIONSBOOMMYBOOMFRIENDBOOM". **Выходные данные**:"WE ARE THE CHAMPIONS MY FRIEND"

# %%
text = input()
text = text.replace('BOOM',' ')
print(text)
# Out:
# BOOMWEBOOMAREBOOMBOOMTHEBOOMCHAMPIONSBOOMMYBOOMFRIENDBOOM
#  WE ARE  THE CHAMPIONS MY FRIEND

# %% [markdown]
# ### Задача 6 Если бы мне платили каждый раз (3 балла)
# Вам дан текст. Необходимо вычислить сколько раз встречается каждое слово в тексте, сколько различных слов было в тексте и сколько всего было слов. Затем замените количество появлений слова в тексте, на его частоту (количество встреч / общее количество слов в тексте). Найдите top 10 самых часто встречающихся слов длины > 3 и выпишите их.
#
# ** Ввод ** <br>
# ['my', 'world', 'my', 'rules']<br>
# ** Вывод**<br>
# {'my':2, 'world':1, 'rules':1}<br>
# Различных слов - 3, всего слов - 4.<br>
# {'my':0.5, 'world':0.25, 'rules':0.25}<br>

# %%
text = '''
Если б мне платили каждый раз
Каждый раз, когда я думаю о тебе
Я бы бомжевала возле трасс
Я бы стала самой бедной из людей
Если б мне платили каждый раз
Каждый раз, когда я думаю о тебе
Я бы бомжевала возле трасс
Я бы стала самой бедной из людей

«Где ты, когда ты не онлайн, когда я жду тебя в сети?
В какие ссылки перейти, чтоб просто оказаться там?
О чём ты думаешь сейчас? Давай среди берёз густых
Читать любимый твой рассказ — страничку я, страничку ты
Или в гости и просто чаю, и сердцами WhatsApp закидан»
Но я снова не отвечаю. Я инкогнито — инкогнида
Но если б мне платили, милый, каждый раз, когда взгляд твой дымный
Мне мерещится где-то мимо, каждый раз, когда снишься ты мне

Если б мне платили каждый раз
Каждый раз, когда я думаю о тебе
Я бы бомжевала возле трасс
Я бы стала самой бедной из людей
Если б мне платили каждый раз
Каждый раз, когда я думаю о тебе
Я бы бомжевала возле трасс
Я бы стала самой бедной из людей

Старая конфорка плещет нам, на двоих одна заварка
За окном темно, в окне трещина, лампочка-луна над парком
Я опять кручу на пальце прядь, пахну, как мамины духи
Ты хочешь меня снять-снять-снять, а я хочу писать стихи-стихи

Уезжай, чай не допивай. Снег или дождь там — уходи
Пусть хоть всего переморосит, пусть хоть торнадо унесёт вдаль
Может, есть ещё твой трамвай? Может, нет? Всё равно иди
Там промозглый седой февраль — он теперь, как и ты, один
И тебя не жаль, не жаль, не жаль. Хоть слоу-мо в дыме сигарет
Даже в миноре и под рояль, даже под грустную скрипку - нет
Если б ты не любил стихи, превратилась бы в звонкий ямб
Если б был наркотою ты, фитоняшкой бы стала я

Если б мне платили каждый раз
Каждый раз, когда я думаю о тебе
Я бы бомжевала возле трасс
Я бы стала самой бедной из людей
Если б мне платили каждый раз
Каждый раз, когда я думаю о тебе
Я бы бомжевала возле трасс
Я бы стала самой бедной из людей'''

# %%
p={}
r={}
text_2=text.lower()
text_1=text_2.split()
c=[',','.','!','?','—','«','»','\n',' ']

for i in range(len(text_1)):
    for j in c:
        if j in str(text_1[i]) and str(j)!=str(text_1[i]):
            text_1[i]=text_1[i].replace(j,'')
#print(text_1)
        
for i in range(len(text_1)):
    p[text_1[i]]=text_1.count(str(text_1[i]))  
    r[text_1[i]]=(round((text_1.count(str(text_1[i])))/len(text_1),3))
g=list(r.values())
#g.sort()
g1=list(r.keys())
h={}
h1={}
for i in range(len(r)):
    for j in range(len(r)):
        if r[g1[i]]==g[j] and len(g1[i])>3:
            h[g1[i]]=g[i]
k=list(h.values())
k.sort()
k1=list(h.keys())

for i in range((len(k)-10),len(k)):
    for j in h:
        #print(k[i],h[j])
        if k[i]==h[j]:
            h1[j]=k[i]
while len(h1)>10:
    for i in h1:
        del h1[i]
        break          
#print(k)        
#print(h1)
print(p,'\n\nразличных слов - '+str(len(p))+', Всего слов - '+str(len(text_1)), end='.')
print('\n\nЗамена количества появлений слова в тексте, на его частоту:\n'+str(r))
print('\n\nTop 10: ',h1)
# Out:
# {'если': 9, 'б': 9, 'мне': 9, 'платили': 7, 'каждый': 14, 'раз': 14, 'когда': 10, 'я': 25, 'думаю': 6, 'о': 7, 'тебе': 6, 'бы': 14, 'бомжевала': 6, 'возле': 6, 'трасс': 6, 'стала': 7, 'самой': 6, 'бедной': 6, 'из': 6, 'людей': 6, 'где': 1, 'ты': 9, 'не': 7, 'онлайн': 1, 'жду': 1, 'тебя': 2, 'в': 7, 'сети': 1, 'какие': 1, 'ссылки': 1, 'перейти': 1, 'чтоб': 1, 'просто': 2, 'оказаться': 1, 'там': 3, 'чём': 1, 'думаешь': 1, 'сейчас': 1, 'давай': 1, 'среди': 1, 'берёз': 1, 'густых': 1, 'читать': 1, 'любимый': 1, 'твой': 3, 'рассказ': 1, '—': 4, 'страничку': 2, 'или': 2, 'гости': 1, 'и': 5, 'чаю': 1, 'сердцами': 1, 'whatsapp': 1, 'закидан': 1, 'но': 2, 'снова': 1, 'отвечаю': 1, 'инкогнито': 1, 'инкогнида': 1, 'милый': 1, 'взгляд': 1, 'дымный': 1, 'мерещится': 1, 'где-то': 1, 'мимо': 1, 'снишься': 1, 'старая': 1, 'конфорка': 1, 'плещет': 1, 'нам': 1, 'на': 2, 'двоих': 1, 'одна': 1, 'заварка': 1, 'за': 1, 'окном': 1, 'темно': 1, 'окне': 1, 'трещина': 1, 'лампочка-луна': 1, 'над': 1, 'парком': 1, 'опять': 1, 'кручу': 1, 'пальце': 1, 'прядь': 1, 'пахну': 1, 'как': 2, 'мамины': 1, 'духи': 1, 'хочешь': 1, 'меня': 1, 'снять-снять-снять': 1, 'а': 1, 'хочу': 1, 'писать': 1, 'стихи-стихи': 1, 'уезжай': 1, 'чай': 1, 'допивай': 1, 'снег': 1, 'дождь': 1, 'уходи': 1, 'пусть': 2, 'хоть': 3, 'всего': 1, 'переморосит': 1, 'торнадо': 1, 'унесёт': 1, 'вдаль': 1, 'может': 2, 'есть': 1, 'ещё': 1, 'трамвай': 1, 'нет': 2, 'всё': 1, 'равно': 1, 'иди': 1, 'промозглый': 1, 'седой': 1, 'февраль': 1, 'он': 1, 'теперь': 1, 'один': 1, 'жаль': 3, 'слоу-мо': 1, 'дыме': 1, 'сигарет': 1, 'даже': 2, 'миноре': 1, 'под': 2, 'рояль': 1, 'грустную': 1, 'скрипку': 1, '-': 1, 'любил': 1, 'стихи': 1, 'превратилась': 1, 'звонкий': 1, 'ямб': 1, 'был': 1, 'наркотою': 1, 'фитоняшкой': 1}
#
# различных слов - 144, Всего слов - 350.
#
# Замена количества появлений слова в тексте, на его частоту:
# {'если': 0.026, 'б': 0.026, 'мне': 0.026, 'платили': 0.02, 'каждый': 0.04, 'раз': 0.04, 'когда': 0.029, 'я': 0.071, 'думаю': 0.017, 'о': 0.02, 'тебе': 0.017, 'бы': 0.04, 'бомжевала': 0.017, 'возле': 0.017, 'трасс': 0.017, 'стала': 0.02, 'самой': 0.017, 'бедной': 0.017, 'из': 0.017, 'людей': 0.017, 'где': 0.003, 'ты': 0.026, 'не': 0.02, 'онлайн': 0.003, 'жду': 0.003, 'тебя': 0.006, 'в': 0.02, 'сети': 0.003, 'какие': 0.003, 'ссылки': 0.003, 'перейти': 0.003, 'чтоб': 0.003, 'просто': 0.006, 'оказаться': 0.003, 'там': 0.009, 'чём': 0.003, 'думаешь': 0.003, 'сейчас': 0.003, 'давай': 0.003, 'среди': 0.003, 'берёз': 0.003, 'густых': 0.003, 'читать': 0.003, 'любимый': 0.003, 'твой': 0.009, 'рассказ': 0.003, '—': 0.011, 'страничку': 0.006, 'или': 0.006, 'гости': 0.003, 'и': 0.014, 'чаю': 0.003, 'сердцами': 0.003, 'whatsapp': 0.003, 'закидан': 0.003, 'но': 0.006, 'снова': 0.003, 'отвечаю': 0.003, 'инкогнито': 0.003, 'инкогнида': 0.003, 'милый': 0.003, 'взгляд': 0.003, 'дымный': 0.003, 'мерещится': 0.003, 'где-то': 0.003, 'мимо': 0.003, 'снишься': 0.003, 'старая': 0.003, 'конфорка': 0.003, 'плещет': 0.003, 'нам': 0.003, 'на': 0.006, 'двоих': 0.003, 'одна': 0.003, 'заварка': 0.003, 'за': 0.003, 'окном': 0.003, 'темно': 0.003, 'окне': 0.003, 'трещина': 0.003, 'лампочка-луна': 0.003, 'над': 0.003, 'парком': 0.003, 'опять': 0.003, 'кручу': 0.003, 'пальце': 0.003, 'прядь': 0.003, 'пахну': 0.003, 'как': 0.006, 'мамины': 0.003, 'духи': 0.003, 'хочешь': 0.003, 'меня': 0.003, 'снять-снять-снять': 0.003, 'а': 0.003, 'хочу': 0.003, 'писать': 0.003, 'стихи-стихи': 0.003, 'уезжай': 0.003, 'чай': 0.003, 'допивай': 0.003, 'снег': 0.003, 'дождь': 0.003, 'уходи': 0.003, 'пусть': 0.006, 'хоть': 0.009, 'всего': 0.003, 'переморосит': 0.003, 'торнадо': 0.003, 'унесёт': 0.003, 'вдаль': 0.003, 'может': 0.006, 'есть': 0.003, 'ещё': 0.003, 'трамвай': 0.003, 'нет': 0.006, 'всё': 0.003, 'равно': 0.003, 'иди': 0.003, 'промозглый': 0.003, 'седой': 0.003, 'февраль': 0.003, 'он': 0.003, 'теперь': 0.003, 'один': 0.003, 'жаль': 0.009, 'слоу-мо': 0.003, 'дыме': 0.003, 'сигарет': 0.003, 'даже': 0.006, 'миноре': 0.003, 'под': 0.006, 'рояль': 0.003, 'грустную': 0.003, 'скрипку': 0.003, '-': 0.003, 'любил': 0.003, 'стихи': 0.003, 'превратилась': 0.003, 'звонкий': 0.003, 'ямб': 0.003, 'был': 0.003, 'наркотою': 0.003, 'фитоняшкой': 0.003}
#
#
# Top 10:  {'возле': 0.017, 'трасс': 0.017, 'самой': 0.017, 'бедной': 0.017, 'людей': 0.017, 'платили': 0.02, 'стала': 0.02, 'если': 0.026, 'когда': 0.029, 'каждый': 0.04}

# %% [markdown]
# ### Задача 7 Последовательные строки (3 балла)
# На вход подается список, состоящий из строк, и целое число $k$. Ваша цель вывести на экран первую встретившуюся самую длинную строку, состоящую из k последовательных элементов списка. Если $k<0$, список пуст или $k >$ длины списка вывести пустую строку.
# <br>**Входные данные**:list = ["cat","city","exception","dog","exception","kick"], $k = 2$. **Выходные данные**: "cityexception"

# %%
a=[]
n=int(input('Введите длину списка: '))
for i in range(n):
    a.append(input('Введите элемент списка (строку): '))
k=input('Введите целое число K: ')

if k=='' or int(k)<=0 or int(k)>n:
    print('""') 
else:
    k=int(k)
    g=[]
    for i in a:
        g.append(len(i))
    h=[]
    for i in range(n-(k-1)):
        h.append(sum(g[i:(i+k)]))
    max=h[0]
    for i in h:
        if i>max:
            max=i
    for i in range(n-(k-1)):
        if sum(g[i:(i+k)])==max:
            print(''.join(a[i:(i+k)]))
            break
# Out:
# Введите длину списка: 6
# Введите элемент списка (строку): cat
# Введите элемент списка (строку): city
# Введите элемент списка (строку): exception
# Введите элемент списка (строку): dog
# Введите элемент списка (строку): exception
# Введите элемент списка (строку): kick
# Введите целое число K: 2
# cityexception

# %% [markdown]
# ### Задача 8 Смайлики (1 балла)
# На вход подается список из смайликов. Правильные смайлики имеют следующую структуру: глаза это ":" или ";", нос - "", "-" или "~", улыбка - ")" или "D". Ваша цель посчитать количество таких смайликов в списке. Пример правильных смайликов: ":-D", ":)", ";-D" ,":~D".
#     <br> **Входные данные**: [':)', ';(', ';}', ':-D']. **Выходные данные**: 2

# %%
a=[]
n=int(input('Введите длину списка: '))
for i in range(n):
    a.append(input('Введите смайлик: '))
p=[':',';','-','~',')','D']
e=[]

for i in a:
    for j in p:
        if j in i:
            e.append(i)
s=' '.join(e)
g={}
for i in range(len(e)):
    g[e[i]]=s.count(str(e[i])) 
gv=list(g.values())
S=0
for i in range(len(a)):
    if len(a[i])==gv[i]:
        S+=1
print('\n',S)
# Out:
# Введите длину списка: 4
# Введите смайлик: :)
# Введите смайлик: ;(
# Введите смайлик: ;}
# Введите смайлик: :-D
#
#  2

# %% [markdown]
# ### Задача 9 "+1" (5 баллов)
# На вход подается строка. Если строка оканчивается на какое-то число, то ваша цель увеличить число на 1. В противном случае дописать 1 в конец строки.
# <br>**Входные данные**: python. **Выходные данные**: python1.
# <br>**Входные данные**: python23. **Выходные данные**: python24.
# <br>**Входные данные**: python099. **Выходные данные**: python100.
# <br>**Входные данные**: python0042. **Выходные данные**: python0043.

# %%
a=input('Введите строку: ')
a1=a.split()
x=[]
if a=='':
    print(a+str(1))
elif (a[len(a)-1].isdigit())==True:
    for i in range(len(a)-1,-1,-1):
        if (a[i].isdigit())==True:
            x.append(a[i])
        else:
            break
    x.reverse()
    x1=''
    for i in x:
        x1=x1+i
    s=int(x1)+1
    S=a[-len(str(x1)):].replace(str((x1)),str(s))
    A=a[:-len((x))]+a[-len((x)):-len(str(S))]+str(S)
    print(A)
else:
    print(a+str(1))
# Out:
# Введите строку: python0042
# python0043

# %% [markdown]
# ### Задача 10 "Волна" (1 балл)
# На вход подается строка. Ваша цель вывести список, в котором буквы в элементах этого списка будет напоминать волну на стадионе, то есть на i позиции буква будет в верхнем регистре.
# <br>**Входные данные**: "python" **Выходные данные**: ["Python","pYthon","pyThon","pytHon","pythOn","pythoN"]
# *Подсказка*: прочитайте про методы upper() и lower() для строк.

# %%
text = input()
for i in range(len(text)):
    if i == 0:
        text = text[i].upper() + text[i+1:]
    elif i != 0:
        text = text[:i-1] + text[i-1].lower() + text[i].upper() + text[i+1:] 
    print(text)
# Out:
# python
# Python
# pYthon
# pyThon
# pytHon
# pythOn
# pythoN
